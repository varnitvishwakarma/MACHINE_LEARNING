# %% [markdown]
# EDA ON FOREST DATA

# %% [markdown]
# data checks to perform
#  1. check missing values
#  2. check duplicates
#  3. check data types
#  4. check the number of unique values of each columns
#  5. check the statistics of data set
#  6. check various categories present in the different categorical columns

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("forest data.csv",header=1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
#mising value

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.isna().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
# Columns which has null values
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
#convert data type into two dataset on the basis of region 


df.loc[:122,'Region']=1
df.loc[122:,'Region']=2
df[['Region']] = df[['Region']].astype(int)

# %%
## handling missing values

# %%
df.dropna().reset_index(drop=True)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          1
# ...

# %%
df.shape
# Out:
# (246, 15)

# %%
## check duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#remoe space from columns name

# %%
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
#convert int columns into int data tyoe

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          1
# 1  not fire          1
# 2  not fire          1
# 3  not fire          1
# 4  not fire          1

# %%
# Column which has string
df.iloc[[122]]
# Out:
#                                day month year Temperature   RH   Ws Rain FFMC  \
# 122  Sidi-Bel Abbes Region Dataset   NaN  NaN         NaN  NaN  NaN  NaN  NaN
#
#      DMC   DC  ISI  BUI  FWI Classes  Region
# 122  NaN  NaN  NaN  NaN  NaN     NaN       2

# %%
#remove 122th column
df= df.drop(122).reset_index(drop=True)

# %%
df[['month','day','year','Temperature','RH','Ws',]] = df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
problematic_rows = df[df.eq('14.6 9').any(axis=1)]
print(problematic_rows)
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature, RH, Ws, Rain, FFMC, DMC, DC, ISI, BUI, FWI, Classes, Region]
# Index: []

# %%
df.iloc[[164]]
# Out:
#      day  month  year  Temperature  RH  Ws Rain  FFMC   DMC    DC  ISI   BUI  \
# 164   18      7  2012           33  68  15    0  86.1  23.9  51.6  5.2  23.9
#
#      FWI  Classes  Region
# 164  9.1  fire          2

# %%
roblematic_rows = df[df.eq('14.6 9').any(axis=1)]
print(problematic_rows)
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature, RH, Ws, Rain, FFMC, DMC, DC, ISI, BUI, FWI, Classes, Region]
# Index: []

# %%
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']]=df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
objects = [features for features in df.columns if df[features].dtypes==int]
for i in objects:
    if i != 'Classes':
        df[i] = df[i].astype(float)

# %%
# check data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          238 non-null    int64
#  1   month        238 non-null    int64
#  2   year         238 non-null    int64
#  3   Temperature  238 non-null    int64
#  4   RH           238 non-null    int64
#  5   Ws           238 non-null    int64
#  6   Rain         238 non-null    float64
#  7   FFMC         238 non-null    float64
#  8   DMC          238 non-null    float64
#  9   DC           238 non-null    float64
#  10  ISI          238 non-null    float64
#  11  BUI          238 non-null    float64
#  12  FWI          238 non-null    float64
#  13  Classes      238 non-null    object
#  14  Region       238 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.0+ KB

# %%
# check the number od unique values of each columns 

df.nunique()
# Out:
# day             31
# month            4
# year             1
# Temperature     19
# RH              61
# Ws              18
# Rain            39
# FFMC           172
# DMC            163
# DC             193
# ISI            105
# BUI            171
# FWI            122
# Classes          8
# Region           2
# dtype: int64

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
# check the dataset is imbalanced or not 

df["Classes"].value_counts()


#conclusion the data is inbalanced
# Out:
# fire             126
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
#check the statistics of data set

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  238.000000  238.000000   238.0   238.000000  238.000000  238.000000
# mean    15.768908    7.512605  2012.0    32.105042   62.037815   15.500000
# std      8.927341    1.124079     0.0     3.627354   14.780912    2.828054
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    6.250000  2012.0    30.000000   53.000000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.750000    8.750000  2012.0    35.000000   73.000000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  238.000000  238.000000  238.000000  238.000000  238.000000  238.000000
# mean     0.776471   77.660504   14.601681   49.770588    4.719328   16.657983
# ...

# %%
df["Classes"].value_counts()
df["Classes"]=df["Classes"].str.strip()

# %%
df["Classes"].value_counts()
# Out:
# fire        132
# not fire    106
# Name: Classes, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
